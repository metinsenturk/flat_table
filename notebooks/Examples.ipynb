# %% [markdown]
# ## Normalization on Yaml Files
#
# Following is an implementation of normalization on `.yaml` files.

# %% [markdown]
# ### Imports

# %%
import os
import sys

# %%
currentdir = os.path.dirname(os.path.realpath('__file__'))
parentdir = os.path.dirname(currentdir)
sys.path.insert(0, parentdir)
currentdir, parentdir
# Out:
# ('/Users/me/Projects/flat_table/notebooks', '/Users/me/Projects/flat_table')

# %%
import yaml
import pandas as pd
import flat_table as norm

# %% [markdown]
# ### Data
#
# The data used here is from [unitedstates/congress-legislators](https://github.com/unitedstates/congress-legislators) repository.
#
# - legislators-historical.yml
# - executive.yml').read
# - committees-current.yml
#
# Download and put them into `data` folder.

# %%
def load_data(filepath):
    with open(filepath) as f:
        contents = yaml.load(f, Loader=yaml.SafeLoader)
    return contents

# %%
source = load_data('../data/legislators-historical.yml')
source2 = load_data('../data/executive.yml')
source3 = load_data('../data/committees-current.yml')

# %% [markdown]
# ### Analysis

# %% [markdown]
# A seri can be transformed into:
#
#     1. Expanded into rows
#     2. Expendad to columns
#     3. Kept as is
#
#     * Each individual seri has parent df name, self name, and self.
#     * if parent and self has the same name ==> it is an object
#     * if parent and

# %% [markdown]
# #### Source 1

# %%
df1 = pd.DataFrame(source)
df1_in = norm.mapper(df1)
df1_in.shape
# Out:
# (68, 4)

# %%
df1.shape
# Out:
# (11982, 7)

# %%
df1_in.tail()
# Out:
#               parent                   child  type  \
# 63  leadership_roles  leadership_roles.title   str
# 64                 .                  family  list
# 65                                    family  dict
# 66            family         family.relation   str
# 67            family             family.name   str
#
#                                                   obj
# 63  0        NaN
# 1        NaN
# 2        NaN
# 3      ...
# 64  0                                             ...
# 65  0                                             ...
# 66  0        NaN
# 1        NaN
# 2        NaN
# 3      ...
# 67  0                      NaN
# 1                  ...

# %%
df1.sample()
# Out:
#                                                      id  \
# 2460  {'bioguide': 'W000692', 'govtrack': 411844, 'i...
#
#                                                    name  \
# 2460  {'first': 'Bradford', 'middle': 'Ripley', 'las...
#
#                                             bio  \
# 2460  {'birthday': '1800-09-03', 'gender': 'M'}
#
#                                                   terms other_names  \
# 2460  [{'type': 'rep', 'start': '1845-12-01', 'end':...         NaN
#
#      leadership_roles family
# 2460              NaN    NaN

# %%
df_norm = norm.normalize(df1_in, is_mapper=True)

# %%
df_norm.shape
# Out:
# (275401, 54)

# %%
df_norm.columns
# Out:
# Index(['index', 'id.maplight', 'id.opensecrets', 'id.ballotpedia', 'id.lis',
#        'id.votesmart', 'id.cspan', 'id.thomas', 'id.house_history_alternate',
#        'id.house_history', 'id.google_entity_id', 'id.wikidata',
#        'id.wikipedia', 'id.icpsr', 'id.govtrack', 'id.bioguide', 'id.fec',
#        'id.bioguide_previous', 'name.official_full', 'name.suffix',
#        'name.nickname', 'name.middle', 'name.last', 'name.first', 'bio.gender',
#        'bio.birthday', 'terms.rss_url', 'terms.state_rank', 'terms.office',
#        'terms.contact_form', 'terms.fax', 'terms.phone', 'terms.address',
#        'terms.url', 'terms.how', 'terms.district', 'terms.party',
#        'terms.class', 'terms.state', 'terms.end', 'terms.start', 'terms.type',
#        'terms.party_affiliations.party', 'terms.party_affiliations.end',
#        'terms.party_affiliations.start', 'other_names.last',
#        'other_names.middle', 'other_names.end', 'leadership_roles.end',
#        'leadership_roles.start', 'leadership_roles.chamber',
#        'leadership_roles.title', 'family.relation', 'family.name'],
#       dtype='object')

# %% [markdown]
# #### Source 2

# %%
df2 = pd.DataFrame(source2)
df2_in = norm.mapper(df2)
df2_in.shape
# Out:
# (31, 4)

# %%
df2.shape
# Out:
# (78, 4)

# %%
df2_in.head()
# Out:
#   parent                child   type  \
# 0      .                   id   dict
# 1     id  id.google_entity_id    str
# 2     id          id.wikidata    str
# 3     id     id.house_history  float
# 4     id         id.wikipedia    str
#
#                                                  obj
# 0  0     {'bioguide': 'W000178', 'govtrack': 4113...
# 1  0              NaN
# 1              NaN
# 2       ...
# 2  0        NaN
# 1        NaN
# 2        NaN
# 3      ...
# 3  0         NaN
# 1         NaN
# 2         NaN
# 3   ...
# 4  0              NaN
# 1              NaN
# 2       ...

# %%
norm.normalize(df2_in)
# Out:
#     index parent                child   type  \
# 0       0      .                   id   dict
# 1       1     id  id.google_entity_id    str
# 2       2     id          id.wikidata    str
# 3       3     id     id.house_history  float
# 4       4     id         id.wikipedia    str
# 5       5     id               id.fec   list
# 6       6                      id.fec    str
# 7       7     id         id.votesmart  float
# 8       8     id       id.opensecrets    str
# 9       9     id               id.lis    str
# 10     10     id            id.thomas    str
# 11     11     id             id.icpsr  float
# 12     12     id        id.icpsr_prez  float
# 13     13     id          id.govtrack    int
# 14     14     id          id.bioguide    str
# 15     15      .                 name   dict
# 16     16   name        name.nickname    str
# 17     17   name          name.middle    str
# 18     18   name          name.suffix    str
# 19     19   name            name.last    str
# 20     20   name           name.first    str
# 21     21      .                  bio   dict
# 22     22    bio           bio.gender    str
# 23     23    bio         bio.birthday    str
# 24     24      .                terms   list
# 25     25                       terms   dict
# 26     26  terms            terms.how    str
# 27     27  terms          terms.party    str
# 28     28  terms            terms.end    str
# 29     29  terms          terms.start    str
# 30     30  terms           terms.type    str
#
#                                                   obj
# 0   0     {'bioguide': 'W000178', 'govtrack': 4113...
# 1   0              NaN
# 1              NaN
# 2       ...
# 2   0        NaN
# 1        NaN
# 2        NaN
# 3      ...
# 3   0         NaN
# 1         NaN
# 2         NaN
# 3   ...
# 4   0              NaN
# 1              NaN
# 2       ...
# 5   0             NaN
# 1             NaN
# 2         ...
# 6   0           NaN
# 1           NaN
# 2           Na...
# 7   0         NaN
# 1         NaN
# 2         NaN
# 3   ...
# 8   0           NaN
# 1           NaN
# 2           Na...
# 9   0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4 ...
# 10  0       NaN
# 1       NaN
# 2       NaN
# 3       Na...
# 11  0         NaN
# 1         NaN
# 2         NaN
# 3   ...
# 12  0     99869.0
# 1     99870.0
# 2     99871.0
# 3   ...
# 13  0     411351
# 1     400699
# 2     405974
# 3     4...
# 14  0     W000178
# 1     A000039
# 2     J000069
# 3   ...
# 15  0             {'first': 'George', 'last': 'Was...
# 16  0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     ...
# 17  0           NaN
# 1           NaN
# 2           Na...
# 18  0     NaN
# 1     NaN
# 2     NaN
# 3     Jr.
# 4     ...
# 19  0     Washington
# 1          Adams
# 2      Jeffe...
# 20  0     George
# 1       John
# 2     Thomas
# 3      ...
# 21  0     {'birthday': '1732-02-22', 'gender': 'M'...
# 22  0     M
# 1     M
# 2     M
# 3     M
# 4     M
#      ....
# 23  0     1732-02-22
# 1     1735-10-19
# 2     1743-0...
# 24  0     [{'type': 'prez', 'start': '1789-04-30',...
# 25  0     {'type': 'prez', 'start': '1789-04-30', ...
# 26  0     election
# 0     election
# 1     election
# 1...
# 27  0       no party
# 0       no party
# 1     Federa...
# 28  0     1793-03-04
# 0     1797-03-04
# 1     1793-0...
# 29  0     1789-04-30
# 0     1793-03-04
# 1     1789-0...
# 30  0         prez
# 0         prez
# 1     viceprez
# 1...

# %% [markdown]
# #### Source 3

# %%
df3 = pd.DataFrame(source3)
df3_in = norm.mapper(df3)
df3_in.shape
# Out:
# (22, 4)

# %%
df3.shape
# Out:
# (49, 16)

# %%
df3_in.head()
# Out:
#   parent         child type                                                obj
# 0      .          type  str  0      house
# 1      house
# 2      house
# 3      ...
# 1      .          name  str  0                        House Committee on Ag...
# 2      .           url  str  0                        https://agriculture.h...
# 3      .  minority_url  str  0            https://republicans-agriculture.h...
# 4      .     thomas_id  str  0     HSAG
# 1     HSAP
# 2     HSAS
# 3     HSBA
# 4 ...

# %%
norm.normalize(df3_in)
# Out:
#     index         parent                    child  type  \
# 0       0              .                     type   str
# 1       1              .                     name   str
# 2       2              .                      url   str
# 3       3              .             minority_url   str
# 4       4              .                thomas_id   str
# 5       5              .       house_committee_id   str
# 6       6              .            subcommittees  list
# 7       7                           subcommittees  dict
# 8       8  subcommittees  subcommittees.wikipedia   str
# 9       9  subcommittees      subcommittees.phone   str
# 10     10  subcommittees    subcommittees.address   str
# 11     11  subcommittees  subcommittees.thomas_id   str
# 12     12  subcommittees       subcommittees.name   str
# 13     13              .                  address   str
# 14     14              .                    phone   str
# 15     15              .                  rss_url   str
# 16     16              .             jurisdiction   str
# 17     17              .      jurisdiction_source   str
# 18     18              .         minority_rss_url   str
# 19     19              .        thomas_id_comment   str
# 20     20              .      senate_committee_id   str
# 21     21              .                wikipedia   str
#
#                                                   obj
# 0   0      house
# 1      house
# 2      house
# 3      ...
# 1   0                        House Committee on Ag...
# 2   0                        https://agriculture.h...
# 3   0            https://republicans-agriculture.h...
# 4   0     HSAG
# 1     HSAP
# 2     HSAS
# 3     HSBA
# 4 ...
# 5   0      AG
# 1      AP
# 2      AS
# 3      BA
# 4     ...
# 6   0     [{'name': 'Conservation and Forestry', '...
# 7   0     {'name': 'Conservation and Forestry', 't...
# 8   0                                             ...
# 9   0     (202) 225-2171
# 0     (202) 225-2171
# 0   ...
# 10  0     1301 LHOB; Washington, DC 20515
# 0     13...
# 11  0      15
# 0      22
# 0      16
# 0      29
# 0     ...
# 12  0                        Conservation and Fore...
# 13  0          1301 LHOB; Washington, DC 20515-600...
# 14  0     (202) 225-2171
# 1     (202) 225-2771
# 2   ...
# 15  0      https://agriculture.house.gov/Rss.aspx?...
# 16  0     The House Committee on Agriculture has l...
# 17  0                                             ...
# 18  0                                             ...
# 19  0                                             ...
# 20  0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4 ...
# 21  0                                             ...
