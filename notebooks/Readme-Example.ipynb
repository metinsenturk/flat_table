# %%
import pandas as pd
import flat_table
from tabulate import tabulate

# %% [markdown]
# ### Example Dataset

# %%
data = [
    (
        1001, 
        { 'first_name': 'john', 'last_name': 'smith', 'phones': {'mobile': '201-..', 'home': '978-..'} }, 
        [{ 'zip': '07014', 'city': 'clifton' }]
    ),
    (
        1002, 
        pd.np.nan, 
        [{'zip': '07014', 'address1': '1 Journal Square'}]
    ),
    (
        1003, 
        { 'first_name': 'marry', 'last_name': 'kate', 'gender': 'female' }, 
        [{ 'zip': '10001', 'city': 'new york' }, { 'zip': '10008', 'city': 'brooklyn' }]
    ),
]

# %%
df = pd.DataFrame(data, columns=['id', 'user_info', 'address'])

# %%
df
# Out:
#      id                                          user_info  \
# 0  1001  {'first_name': 'john', 'last_name': 'smith', '...
# 1  1002                                                NaN
# 2  1003  {'first_name': 'marry', 'last_name': 'kate', '...
#
#                                              address
# 0              [{'zip': '07014', 'city': 'clifton'}]
# 1  [{'zip': '07014', 'address1': '1 Journal Squar...
# 2  [{'zip': '10001', 'city': 'new york'}, {'zip':...

# %% [markdown]
# ### Using flat_table

# %%
flat_table.normalize(df)
# Out:
#    index    id  gender phones.home phones.mobile last_name first_name  \
# 0      0  1001     NaN      978-..        201-..     smith       john
# 1      1  1002     NaN         NaN           NaN       NaN        NaN
# 2      2  1003  female         NaN           NaN      kate      marry
# 3      2  1003  female         NaN           NaN      kate      marry
#
#            address1      city    zip
# 0               NaN   clifton  07014
# 1  1 Journal Square       NaN  07014
# 2               NaN  new york  10001
# 3               NaN  brooklyn  10008

# %% [markdown]
# ### Mapper function

# %%
mapper = flat_table.mapper(df)
mapper
# Out:
#               parent          child  type  \
# 0                  .             id   int
# 1                  .      user_info  dict
# 2         .user_info         gender   str
# 3         .user_info    phones.home   str
# 4         .user_info  phones.mobile   str
# 5         .user_info      last_name   str
# 6         .user_info     first_name   str
# 7                  .        address  list
# 8           .address        address  dict
# 9   .address.address       address1   str
# 10  .address.address           city   str
# 11  .address.address            zip   str
#
#                                                   obj
# 0   0    1001
# 1    1002
# 2    1003
# Name: id, dtype:...
# 1   0    {'first_name': 'john', 'last_name': 'smit...
# 2   0       NaN
# 1       NaN
# 2    female
# Name: gend...
# 3   0    978-..
# 1       NaN
# 2       NaN
# Name: phon...
# 4   0    201-..
# 1       NaN
# 2       NaN
# Name: phon...
# 5   0    smith
# 1      NaN
# 2     kate
# Name: last_na...
# 6   0     john
# 1      NaN
# 2    marry
# Name: first_n...
# 7   0                [{'zip': '07014', 'city': 'cl...
# 8   0                 {'zip': '07014', 'city': 'cl...
# 9   0                 NaN
# 1    1 Journal Square
# 2 ...
# 10  0     clifton
# 1         NaN
# 2    new york
# 2   ...
# 11  0    07014
# 1    07014
# 2    10001
# 2    10008
# Na...

# %%
print(tabulate(flat_table.normalize(df), tablefmt="pipe", headers="keys"))

# %% [markdown]
# ### Comparison with json_normalize()

# %%
pd.io.json.json_normalize(df.user_info)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-105-84ca9b38918b> in <module>
# ----> 1 pd.io.json.json_normalize(df.user_info)
#
# /Applications/anaconda3/envs/normenv/lib/python3.7/site-packages/pandas/io/json/_normalize.py in json_normalize(data, record_path, meta, meta_prefix, record_prefix, errors, sep, max_level)
#     264             # TODO: handle record value which are lists, at least error
#     265             #       reasonably
# --> 266             data = nested_to_record(data, sep=sep, max_level=max_level)
#     267         return DataFrame(data)
#     268     elif not isinstance(record_path, list):
#
# /Applications/anaconda3/envs/normenv/lib/python3.7/site-packages/pandas/io/json/_normalize.py in nested_to_record(ds, prefix, sep, level, max_level)
#      82     for d in ds:
#      83         new_d = copy.deepcopy(d)
# ---> 84         for k, v in d.items():
#      85             # each key gets renamed with prefix
#      86             if not isinstance(k, str):
#
# AttributeError: 'float' object has no attribute 'items'
