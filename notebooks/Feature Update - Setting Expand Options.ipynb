# %% [markdown]
# # Adding Settings to Normalize
#
# In this notebook, the feature update to add the switch of whether or not to expand lists and dicts is tested.

# %% [markdown]
# ## Imports

# %%
import os
import sys
sys.path.insert(0, os.pardir)

# %%
import pandas as pd
from flat_table import mapper, normalize

# %% [markdown]
# ## Sample Dataframe

# %%
data = [
    (
        1001, 
        { 'first_name': 'john', 'last_name': 'smith', 'phones': {'mobile': '201-..', 'home': '978-..'} },
        ['a', 'b'],
        [{ 'zip': '07014', 'city': 'clifton' }],
        { 'membership': True, 'memberid': '1231' }
    ),
    (
        1002, 
        pd.np.nan, 
        ['one', 'two', 'three', 'four'],
        [{'zip': '07014', 'address1': '1 Journal Square'}],
        { 'membership': False, 'memberid': '' }
    ),
    (
        1003, 
        { 'first_name': 'marry', 'last_name': 'kate', 'gender': 'female' }, 
        ['w', 'y', 'z'],
        [{ 'zip': '10001', 'city': 'new york' }, { 'zip': '10008', 'city': 'brooklyn' }],
        { 'membership': True, 'memberid': '9754' }
    ),
]
df = pd.DataFrame(data, columns=['id', 'user_info', 'name_list', 'address', 'membership'])

# %%
df.head()
# Out:
#      id                                          user_info  \
# 0  1001  {'first_name': 'john', 'last_name': 'smith', '...
# 1  1002                                                NaN
# 2  1003  {'first_name': 'marry', 'last_name': 'kate', '...
#
#                  name_list                                            address  \
# 0                   [a, b]              [{'zip': '07014', 'city': 'clifton'}]
# 1  [one, two, three, four]  [{'zip': '07014', 'address1': '1 Journal Squar...
# 2                [w, y, z]  [{'zip': '10001', 'city': 'new york'}, {'zip':...
#
#                                  membership
# 0  {'membership': True, 'memberid': '1231'}
# 1     {'membership': False, 'memberid': ''}
# 2  {'membership': True, 'memberid': '9754'}

# %% [markdown]
# ## Setttings

# %%
mp = mapper(df)
mp
# Out:
#         parent                    child  type  \
# 0            .                       id   int
# 1            .                user_info  dict
# 2    user_info         user_info.gender   str
# 3    user_info    user_info.phones.home   str
# 4    user_info  user_info.phones.mobile   str
# 5    user_info      user_info.last_name   str
# 6    user_info     user_info.first_name   str
# 7            .                name_list  list
# 8                             name_list   str
# 9            .                  address  list
# 10                              address  dict
# 11     address         address.address1   str
# 12     address             address.city   str
# 13     address              address.zip   str
# 14           .               membership  dict
# 15  membership      membership.memberid   str
# 16  membership    membership.membership  bool
#
#                                                   obj
# 0   0    1001
# 1    1002
# 2    1003
# Name: id, dtype:...
# 1   0    {'first_name': 'john', 'last_name': 'smit...
# 2   0       NaN
# 1       NaN
# 2    female
# Name: user...
# 3   0    978-..
# 1       NaN
# 2       NaN
# Name: user...
# 4   0    201-..
# 1       NaN
# 2       NaN
# Name: user...
# 5   0    smith
# 1      NaN
# 2     kate
# Name: user_in...
# 6   0     john
# 1      NaN
# 2    marry
# Name: user_in...
# 7   0                     [a, b]
# 1    [one, two, t...
# 8   0        a
# 0        b
# 1      one
# 1      two
# 1 ...
# 9   0                [{'zip': '07014', 'city': 'cl...
# 10  0                 {'zip': '07014', 'city': 'cl...
# 11  0                 NaN
# 1    1 Journal Square
# 2 ...
# 12  0     clifton
# 1         NaN
# 2    new york
# 2   ...
# 13  0    07014
# 1    07014
# 2    10001
# 2    10008
# Na...
# 14  0    {'membership': True, 'memberid': '1231'}
# ...
# 15  0    1231
# 1
# 2    9754
# Name: membership...
# 16  0     True
# 1    False
# 2     True
# Name: members...

# %% [markdown]
# ### Find Original Df

# %%
org_df = mp[mp.parent == '.']
org_df
# Out:
#    parent       child  type                                                obj
# 0       .          id   int  0    1001
# 1    1002
# 2    1003
# Name: id, dtype:...
# 1       .   user_info  dict  0    {'first_name': 'john', 'last_name': 'smit...
# 7       .   name_list  list  0                     [a, b]
# 1    [one, two, t...
# 9       .     address  list  0                [{'zip': '07014', 'city': 'cl...
# 14      .  membership  dict  0    {'membership': True, 'memberid': '1231'}
# ...

# %% [markdown]
# ### Settings

# %%
expand_dicts = False
expand_lists = False

if expand_dicts and expand_lists:
    dataframe = mp[(mp.type != 'dict') & (mp.type != 'list')]
# dicts expand, lists are same
elif expand_dicts and not expand_lists:
    print('dict True list False')
    org_df = mp[mp.parent == '.']
    dict_items = org_df[org_df.type == 'dict'].child
    final_dict_items = mp[mp.parent.isin(dict_items)]
    final_others = org_df[org_df.type != 'dict']
    dataframe = pd.concat([final_dict_items, final_others]).sort_index()
# dicts are same, lists expand
elif not expand_dicts and expand_lists:
    print('dict False list True')
    org_df = mp[mp.parent == '.']
    list_items = mp[mp.type == 'list'].child
    final_list_items = mp[
        (mp.parent.isin(list_items) | mp.child.isin(list_items)) 
        & ~mp.type.isin(['dict', 'list'])]
    final_others = org_df[org_df.type != 'list']
    dataframe = pd.concat([final_list_items, final_others]).sort_index()
# original df
else:
    dataframe = mp[mp.parent == '.']
dataframe
# Out:
#    parent       child  type                                                obj
# 0       .          id   int  0    1001
# 1    1002
# 2    1003
# Name: id, dtype:...
# 1       .   user_info  dict  0    {'first_name': 'john', 'last_name': 'smit...
# 7       .   name_list  list  0                     [a, b]
# 1    [one, two, t...
# 9       .     address  list  0                [{'zip': '07014', 'city': 'cl...
# 14      .  membership  dict  0    {'membership': True, 'memberid': '1231'}
# ...

# %% [markdown]
# ### After Implementation

# %%
normalize(df, expand_dicts=True, expand_lists=False)
# Out:
# dict True list False
#    index    id                name_list  \
# 0      0  1001                   [a, b]
# 1      1  1002  [one, two, three, four]
# 2      2  1003                [w, y, z]
#
#                                              address user_info.gender  \
# 0              [{'zip': '07014', 'city': 'clifton'}]              NaN
# 1  [{'zip': '07014', 'address1': '1 Journal Squar...              NaN
# 2  [{'zip': '10001', 'city': 'new york'}, {'zip':...           female
#
#   user_info.phones.home user_info.phones.mobile user_info.last_name  \
# 0                978-..                  201-..               smith
# 1                   NaN                     NaN                 NaN
# 2                   NaN                     NaN                kate
#
#   user_info.first_name membership.memberid membership.membership
# 0                 john                1231                  True
# 1                  NaN                                     False
# 2                marry                9754                  True

# %%
normalize(df, expand_dicts=False, expand_lists=True)
# Out:
# dict False list True
#     index    id                                          user_info  \
# 0       0  1001  {'first_name': 'john', 'last_name': 'smith', '...
# 1       0  1001  {'first_name': 'john', 'last_name': 'smith', '...
# 2       1  1002                                                NaN
# 3       1  1002                                                NaN
# 4       1  1002                                                NaN
# 5       1  1002                                                NaN
# 6       2  1003  {'first_name': 'marry', 'last_name': 'kate', '...
# 7       2  1003  {'first_name': 'marry', 'last_name': 'kate', '...
# 8       2  1003  {'first_name': 'marry', 'last_name': 'kate', '...
# 9       2  1003  {'first_name': 'marry', 'last_name': 'kate', '...
# 10      2  1003  {'first_name': 'marry', 'last_name': 'kate', '...
# 11      2  1003  {'first_name': 'marry', 'last_name': 'kate', '...
#
#                                   membership name_list  address.address1  \
# 0   {'membership': True, 'memberid': '1231'}         a               NaN
# 1   {'membership': True, 'memberid': '1231'}         b               NaN
# 2      {'membership': False, 'memberid': ''}       one  1 Journal Square
# 3      {'membership': False, 'memberid': ''}       two  1 Journal Square
# 4      {'membership': False, 'memberid': ''}     three  1 Journal Square
# 5      {'membership': False, 'memberid': ''}      four  1 Journal Square
# 6   {'membership': True, 'memberid': '9754'}         w               NaN
# 7   {'membership': True, 'memberid': '9754'}         w               NaN
# 8   {'membership': True, 'memberid': '9754'}         y               NaN
# 9   {'membership': True, 'memberid': '9754'}         y               NaN
# 10  {'membership': True, 'memberid': '9754'}         z               NaN
# 11  {'membership': True, 'memberid': '9754'}         z               NaN
#
#    address.city address.zip
# 0       clifton       07014
# 1       clifton       07014
# 2           NaN       07014
# 3           NaN       07014
# 4           NaN       07014
# 5           NaN       07014
# 6      new york       10001
# 7      brooklyn       10008
# 8      new york       10001
# 9      brooklyn       10008
# 10     new york       10001
# 11     brooklyn       10008
